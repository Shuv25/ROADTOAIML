# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
df=pd.read_csv("D:\\DATASETS\\shampoo_sales.csv")
df.head()
# Out:
#   Month  Sales
# 0  1-01  266.0
# 1  1-02  145.9
# 2  1-03  183.1
# 3  1-04  119.3
# 4  1-05  180.3

# %%
df["Month"] = "200" + df["Month"]

# %%
df.set_index("Month",inplace=True)
df.index=pd.to_datetime(df.index)
df.dropna(inplace=True)

# %%
df.head()
# Out:
#             Sales
# Month
# 2001-01-01  266.0
# 2001-02-01  145.9
# 2001-03-01  183.1
# 2001-04-01  119.3
# 2001-05-01  180.3

# %%
plot_acf(df['Sales'],lags=12)#no of lags depends upon the seasonality
plt.show()

# %%
plot_pacf(df['Sales'],lags=12)
plt.show()
