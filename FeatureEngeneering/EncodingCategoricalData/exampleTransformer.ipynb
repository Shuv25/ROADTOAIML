# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\\DATASETS\\customer.csv")
df.head()
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No
# 3   72  Female     Good        PG        No
# 4   16  Female  Average        UG        No

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop('purchased',axis=1),df['purchased'],test_size=0.2, random_state=56)

# %%
X_train
# Out:
#     age  gender   review education
# 4    16  Female  Average        UG
# 18   19    Male     Good    School
# 8    65  Female  Average        UG
# 46   64  Female     Poor        PG
# 39   76    Male     Poor        PG
# 30   73    Male  Average        UG
# 6    18    Male     Good    School
# 13   57  Female  Average    School
# 33   89  Female     Good        PG
# 1    68  Female     Poor        UG
# 31   22  Female     Poor    School
# 27   69  Female     Poor        PG
# 9    74    Male     Good        UG
# 29   83  Female  Average        UG
# 19   97    Male     Poor        PG
# 32   92    Male  Average        UG
# 47   38  Female     Good        PG
# 35   74    Male     Poor    School
# 49   25  Female     Good        UG
# 5    31  Female  Average    School
# 28   48    Male     Poor    School
# 10   98  Female     Good        UG
# 25   57  Female     Good    School
# 16   59    Male     Poor        UG
# 11   74    Male     Good        UG
# 2    70  Female     Good        PG
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
df.head(3)
# Out:
#    age  gender   review education purchased
# 0   30  Female  Average    School        No
# 1   68  Female     Poor        UG        No
# 2   70  Female     Good        PG        No

# %%
from sklearn.compose import ColumnTransformer

# %%
X_train
# Out:
#     age  gender   review education
# 4    16  Female  Average        UG
# 18   19    Male     Good    School
# 8    65  Female  Average        UG
# 46   64  Female     Poor        PG
# 39   76    Male     Poor        PG
# 30   73    Male  Average        UG
# 6    18    Male     Good    School
# 13   57  Female  Average    School
# 33   89  Female     Good        PG
# 1    68  Female     Poor        UG
# 31   22  Female     Poor    School
# 27   69  Female     Poor        PG
# 9    74    Male     Good        UG
# 29   83  Female  Average        UG
# 19   97    Male     Poor        PG
# 32   92    Male  Average        UG
# 47   38  Female     Good        PG
# 35   74    Male     Poor    School
# 49   25  Female     Good        UG
# 5    31  Female  Average    School
# 28   48    Male     Poor    School
# 10   98  Female     Good        UG
# 25   57  Female     Good    School
# 16   59    Male     Poor        UG
# 11   74    Male     Good        UG
# 2    70  Female     Good        PG
# ...

# %%
trans=ColumnTransformer(transformers=[
    ('tnfone',OneHotEncoder(drop='first',sparse_output=False),['gender']),
    ('tnftwo',OrdinalEncoder(categories=[['Poor','Average','Good'],['School','UG','PG']]),['review','education'])],
    remainder='passthrough')

# %%
trans.fit_transform(X_train).shape
# Out:
# (40, 4)

# %%
trans.transform(X_train)
# Out:
# array([[ 0.,  1.,  1., 16.],
#        [ 1.,  2.,  0., 19.],
#        [ 0.,  1.,  1., 65.],
#        [ 0.,  0.,  2., 64.],
#        [ 1.,  0.,  2., 76.],
#        [ 1.,  1.,  1., 73.],
#        [ 1.,  2.,  0., 18.],
#        [ 0.,  1.,  0., 57.],
#        [ 0.,  2.,  2., 89.],
#        [ 0.,  0.,  1., 68.],
#        [ 0.,  0.,  0., 22.],
#        [ 0.,  0.,  2., 69.],
#        [ 1.,  2.,  1., 74.],
#        [ 0.,  1.,  1., 83.],
#        [ 1.,  0.,  2., 97.],
#        [ 1.,  1.,  1., 92.],
#        [ 0.,  2.,  2., 38.],
#        [ 1.,  0.,  0., 74.],
#        [ 0.,  2.,  1., 25.],
#        [ 0.,  1.,  0., 31.],
#        [ 1.,  0.,  0., 48.],
#        [ 0.,  2.,  1., 98.],
#        [ 0.,  2.,  0., 57.],
#        [ 1.,  0.,  1., 59.],
#        [ 1.,  2.,  1., 74.],
#        [ 0.,  2.,  2., 70.],
#        [ 1.,  0.,  0., 51.],
#        [ 0.,  1.,  2., 16.],
#        [ 0.,  0.,  2., 53.],
#        [ 0.,  2.,  1., 39.],
#        [ 0.,  0.,  2., 18.],
#        [ 0.,  2.,  0., 96.],
# ...

# %%
trans.transform(X_test).shape
# Out:
# (10, 4)
